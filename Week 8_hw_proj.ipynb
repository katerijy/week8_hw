# %%
# # AirBnB NY Locations Data Case Study
# In this final project, you task will be to take the data provided and 
#find evidence to answer the following questions

# %%
#############answers follow code in comments#############

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('./AB_NYC_2019.csv', sep=',')

# %%
busy = air_bnb.query('availability_365 == 0')
busy_host = busy.drop(columns=['id','neighbourhood_group',
       'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'number_of_reviews', 'last_review',
       'reviews_per_month','name', 'availability_365'])
busy_host
# Out:
#          host_id      host_name  calculated_host_listings_count
# 4           7192          Laura                               1
# 6           7356          Garon                               1
# 8           7490      MaryEllen                               1
# 14         11975          Alina                               1
# 20         21207          Chaya                               1
# ...          ...            ...                             ...
# 48550   16883913        Tiffany                               1
# 48731  121384174  Luciana Paula                               1
# 48756  273824202          David                               1
# 48760   19990280        Brandon                               1
# 48779   13384464         Hollie                               1
#
# [17533 rows x 3 columns]

# %%
print(type(busy_host))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
busiest = busy_host.query('calculated_host_listings_count != 1')
sorted = busiest.sort_values("calculated_host_listings_count", kind = "mergesort", ascending=False)

# %%
busiest.query("calculated_host_listings_count >90")
# Out:
#          host_id          host_name  calculated_host_listings_count
# 14700   61391963  Corporate Housing                              91
# 16774   61391963  Corporate Housing                              91
# 16804   61391963  Corporate Housing                              91
# 17952   16098958     Jeremy & Laura                              96
# 19354   16098958     Jeremy & Laura                              96
# 28509   61391963  Corporate Housing                              91
# 33117   61391963  Corporate Housing                              91
# 33684  137358866             Kazuya                             103
# 33688  137358866             Kazuya                             103
# 34474   16098958     Jeremy & Laura                              96
# 35184  137358866             Kazuya                             103
# 37353  137358866             Kazuya                             103
# 37949   16098958     Jeremy & Laura                              96
# ...

# %%
##1: Which hosts are the busiest and why?

#Of the 17k+ hosts who have zero availability, Kazuya is the busiest because he also has the most listings at 103. 
#Closely behind are Jeremy&Laura with 96 listings and Corporate Housing with 91 listings

# %%
air_bnb = pd.read_csv('./AB_NYC_2019.csv', sep=',')
air_bnb.keys()
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
air_bnb.groupby('neighbourhood_group', as_index=False).count()
# Out:
#   neighbourhood_group     id   name  host_id  host_name  neighbourhood  \
# 0               Bronx   1091   1090     1091       1090           1091
# 1            Brooklyn  20104  20098    20104      20095          20104
# 2           Manhattan  21661  21652    21661      21652          21661
# 3              Queens   5666   5666     5666       5664           5666
# 4       Staten Island    373    373      373        373            373
#
#    latitude  longitude  room_type  price  minimum_nights  number_of_reviews  \
# 0      1091       1091       1091   1091            1091               1091
# 1     20104      20104      20104  20104           20104              20104
# 2     21661      21661      21661  21661           21661              21661
# 3      5666       5666       5666   5666            5666               5666
# 4       373        373        373    373             373                373
#
#    last_review  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
##2 How many neighborhood groups are available and which shows up the most?

#There are 5 neighborhood groups and Manhattan contains the most listings.

# %%
manhattan = busy.drop(columns=['neighbourhood_group',
       'neighbourhood', 'latitude', 'longitude', 'price',
       'minimum_nights', 'number_of_reviews', 'last_review',
       'reviews_per_month','name', 'host_id', 'host_name'])
manhattan
# Out:
#              id        room_type  calculated_host_listings_count  \
# 4          5022  Entire home/apt                               1
# 6          5121     Private room                               1
# 8          5203     Private room                               1
# 14         6090  Entire home/apt                               1
# 20         7801  Entire home/apt                               1
# ...         ...              ...                             ...
# 48550  36313048     Private room                               1
# 48731  36410519  Entire home/apt                               1
# 48756  36419441  Entire home/apt                               1
# 48760  36420725     Private room                               1
# 48779  36424776     Private room                               1
#
#        availability_365
# 4                     0
# 6                     0
# 8                     0
# 14                    0
# 20                    0
# ...                 ...
# ...

# %%
bestroom = manhattan.sort_values("room_type", kind = "mergesort", ascending=False)
bestroom
# Out:
#              id        room_type  calculated_host_listings_count  \
# 357       99070      Shared room                               2
# 545      200645      Shared room                               1
# 944      361803      Shared room                               1
# 1175     502132      Shared room                               2
# 1413     633950      Shared room                               1
# ...         ...              ...                             ...
# 48264  36169764  Entire home/apt                               1
# 48346  36207556  Entire home/apt                               1
# 48450  36270864  Entire home/apt                               1
# 48731  36410519  Entire home/apt                               1
# 48756  36419441  Entire home/apt                               1
#
#        availability_365
# 357                   0
# 545                   0
# 944                   0
# 1175                  0
# 1413                  0
# ...                 ...
# ...

# %%
bestroom.describe(include = "all")
# Out:
#                   id        room_type  calculated_host_listings_count  \
# count   1.753300e+04            17533                    17533.000000
# unique           NaN                3                             NaN
# top              NaN  Entire home/apt                             NaN
# freq             NaN             8876                             NaN
# mean    1.546172e+07              NaN                        1.437746
# std     8.983375e+06              NaN                        3.792782
# min     5.022000e+03              NaN                        1.000000
# 25%     8.011605e+06              NaN                        1.000000
# 50%     1.417912e+07              NaN                        1.000000
# 75%     2.200160e+07              NaN                        1.000000
# max     3.642478e+07              NaN                      103.000000
#
#         availability_365
# count            17533.0
# unique               NaN
# top                  NaN
# ...

# %%
##3 Are private rooms the most popular in manhattan?

# No, entire home/apt are most popular in manhattan

# %%
air_bnb.groupby('neighbourhood_group', as_index=False).mean()
# Out:
#   neighbourhood_group            id       host_id   latitude  longitude  \
# 0               Bronx  2.273492e+07  1.056099e+08  40.848305 -73.884552
# 1            Brooklyn  1.825685e+07  5.671526e+07  40.685036 -73.951190
# 2           Manhattan  1.877494e+07  6.783062e+07  40.765062 -73.974607
# 3              Queens  2.175500e+07  9.615680e+07  40.731531 -73.872775
# 4       Staten Island  2.159747e+07  9.853360e+07  40.610225 -74.105805
#
#         price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0   87.496792        4.560953          26.004583           1.837831
# 1  124.383207        6.056556          24.202845           1.283212
# 2  196.875814        8.579151          20.985596           1.272131
# 3   99.517649        5.181433          27.700318           1.941200
# 4  114.812332        4.831099          30.941019           1.872580
#
#    calculated_host_listings_count  availability_365
# 0                        2.233731        165.758937
# ...

# %%
##4 Which neighorhood group has the highest average price?

# Manhattan has the highest average price at $197

# %%
def make_nightlycost(row):
    price = row['price']
    night = row['minimum_nights']
    nightly = price/night
    return nightly
air_bnb['nightly'] = air_bnb.apply(make_nightlycost, axis=1)
air_bnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
air_bnb.describe(include = 'all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %%
air_bnb.groupby('neighbourhood_group').sum()
# Out:
#                                id        host_id      latitude     longitude  \
# neighbourhood_group
# Bronx                 24803796188   115220380205   44565.50071 -8.060805e+04
# Brooklyn             367035792483  1140203577483  817931.96821 -1.486715e+06
# Manhattan            406683958152  1469279004836  883012.01680 -1.602364e+06
# Queens               123263814259   544824426112  230784.85597 -4.185631e+05
# Staten Island          8055857451    36753031930   15147.61383 -2.764147e+04
#
#                        price  minimum_nights  number_of_reviews  \
# neighbourhood_group
# Bronx                  95459            4976              28371
# Brooklyn             2500600          121761             486574
# Manhattan            4264527          185833             454569
# Queens                563867           29358             156950
# Staten Island          42825            1802              11541
#
#                      reviews_per_month  calculated_host_listings_count  \
# ...

# %%
##5 Which neighborhood group has the highest total price?

#Manhattan at 4364527

# %%
air_bnb.groupby('host_name').sum().sort_values('price', ascending=False)
# Out:
#                             id      host_id     latitude    longitude  price  \
# host_name
# Sonder (NYC)       10885561678  71782340547  13316.25823 -24198.18856  82795
# Blueground          7210036953  24924786136   9451.60418 -17166.13165  70331
# Michael             7430617239  22673153604  16984.89137 -30841.28573  66895
# David               7943862898  28633613354  16414.34392 -29804.53757  65844
# Alex                5496620312  19850092761  11361.10533 -20635.86235  52563
# ...                        ...          ...          ...          ...    ...
# Carolann              16927533      3737986     40.70588    -74.01590     12
# Vishanti & Jeremy     21869057     11967922     40.72421    -73.95364     10
# Salim                 24114389    180661875     40.76844    -73.98333     10
# Qiuchi                20933849     13709292     40.75091    -73.97597      0
# Aymeric               20624541     10132166     40.70838    -73.94645      0
#
# ...

# %%
##6 Which top 5 hosts have the highest total price?

#hosts: Sonder, Blueground, Michael, David, and Alex have have the highest total prices.

# %%
bestandbusy = busy.sort_values('number_of_re', kind = "mergesort", ascending=False)
bestandbusy
# Out:
#              id                                               name    host_id  \
# 471      166172                    LG Private Room/Family Friendly     792159
# 9974    7670562       JFK 10 & LGA 15 MINUTES A/C  PRIVATE BEDROOM   22959695
# 9976    7675781  JFK 10 & LGA 15 MINUTES  AWAY  A/C PRIVATE BED...   22959695
# 22104  17779504  Relaxing Quiet Room Just 6 Mins from JFK Airport!  121391142
# 5876    4282178                     A Superhost SALE! DELUXE Room!   21641206
# ...         ...                                                ...        ...
# 48550  36313048    Sunny room with private entrance in shared home   16883913
# 48731  36410519    Sunlight charming apt. in the heart of Brooklyn  121384174
# 48756  36419441                            Murray Hill Masterpiece  273824202
# 48760  36420725  Sunnyside, Queens 15 Mins to Midtown Clean & C...   19990280
# 48779  36424776  Queen size bedroom in two bed apt with great l...   13384464
#
# ...

# %%
##7 Which hosts are the busiest and based on their reviews?

# Wanda, Gurpreet both are the busiest with 0 availability and over 480 reviews however they average 
#6-8 reviews per month whereas Deloris has 368 reviews but average 13 reviews per month so I would say that 
#Deloris is busiest with the most turn around in a month

# %%
air_bnb = pd.read_csv('./AB_NYC_2019.csv', sep=',')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
busy.query('number_of_reviews >100')
# Out:
#              id                                       name    host_id  \
# 8          5203         Cozy Clean Guest Room - Family Apt       7490
# 94        20913         Charming 1 bed GR8 WBurg LOCATION!      79402
# 132       30031           NYC artists’ loft with roof deck     129352
# 174       44221             Financial District Luxury Loft     193722
# 180       45556      Fort Greene, Brooklyn: Center Bedroom      67778
# ...         ...                                        ...        ...
# 29581  22705516         The Quietest Block in Manhattan :)  127740507
# 30461  23574142                          queens get away!!  176185168
# 31250  24267706  entire sunshine of the spotless mind room   21074914
# 32670  25719044                COZY Room for Female Guests   40119874
# 35014  27759146     Cozy corner near Empire State Building  209549523
#
#         host_name neighbourhood_group              neighbourhood  latitude  \
# ...

# %%
##8 Who currently has no (zero) availability with a review count of 100 or more?

# See above 158 hosts

# %%
abb_dropped = air_bnb.dropna()
abb_dropped
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %%
def make_nightlycost(row):
    price = row['price']
    night = row['minimum_nights']
    nightly = price/night
    return nightly
air_bnb['nightly'] = air_bnb.apply(make_nightlycost, axis=1)
air_bnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
mostexpensive = air_bnb.sort_values('nightly', kind='mergesort', ascending=False,)
mostexpensive
# Out:
#              id                                               name    host_id  \
# 4377    2953058                                      Film Location    1177497
# 29662  22779726          East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 42523  33007610                70' Luxury MotorYacht on the Hudson    7407743
# 45666  34895693                               Gem of east Flatbush  262534951
# 44034  33998396                   3000 sq ft daylight photo studio    3750764
# ...         ...                                                ...        ...
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
#
# ...

# %%
##9 What host has the highest total of prices and where are they located?

#Jessica from Brooklyn has the most expensive place at $8000 per night

# %%
search = air_bnb.query('host_name == Danielle') #this didnt work so i'll try a longer way

# %%
air_bnb[air_bnb['host_name']=='Danielle'].sort_values('neighbourhood')
# Out:
#              id                                               name    host_id  \
# 16349  13151075                    ASTORIA APARTMENT OUTDOOR SPACE   18051286
# 27021  21386105  Quiet & clean 1br haven with balcony near the ...  154256662
# 14239  11031059                 Private Room in Bedstuy Brownstone   44776542
# 12519   9618986                1 Bedrom Apt(One Block From Subway)   49764808
# 24499  19710855  Cozy Ground Floor Apartment-SUBWAY ONE BLOCK AWAY   49764808
# ...         ...                                                ...        ...
# 11547   8986585                  Williamsburg Two Bedroom/Two Bath   46946480
# 12412   9571665                  Brightly Tucked into Williamsburg    1401835
# 15654  12643171                            Sunny Cozy Loft Bedroom   26054687
# 5495    3973944                Ground & Rejuvenate PR Williamsburg    1401835
# 5717    4163781                  Sun Soaked & Cozy PR Williamsburg    1401835
#
# ...

# %%
##10 When did Danielle from Queens last receive a review?

# Danielle's last review was on 2018-01-02
